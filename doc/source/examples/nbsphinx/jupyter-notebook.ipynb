# %% [markdown]
# # Nbsphinx example
# This is an example for rendering of nb sphinx with ansys-sphinx-theme.

# %% [markdown]
# ## Plotting a simple sphere using pyvista.

# %%
import pyvista as pv

# Create a sphere mesh
sphere = pv.Sphere()

# Plot the sphere
p = pv.Plotter()
p.add_mesh(sphere, color='blue')
p.show()
# Out:
# c:\Users\rvenugop\ansys\ansys-sphinx-theme\.venv\Lib\site-packages\pyvista\jupyter\notebook.py:34: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ## Rending equations using Math.

# %%
from IPython.display import Math
eq = Math(r'\int\limits_{-\infty}^\infty f(x) \delta(x - x_0) dx = f(x_0)')
eq
# Out:
# $\displaystyle \int\limits_{-\infty}^\infty f(x) \delta(x - x_0) dx = f(x_0)$

# %%
from IPython.display import Latex
Latex(r'This is a \LaTeX{} equation: $a^2 + b^2 = c^2$')
# Out:
# This is a \LaTeX{} equation: $a^2 + b^2 = c^2$

# %% [markdown]
# ## Rendering a table in markdown.

# %% [markdown]
# This is an example to render the table inside the notebook
#
# A     | B     | A and B
# ------|-------|--------
# False | False | False
# True  | False | False
# False | True  | False
# True  | True  | True
